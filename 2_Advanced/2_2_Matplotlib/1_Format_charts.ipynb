# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
from matplotlib.ticker import MaxNLocator

schedules = ['Full-time', 'Part-time', 'Contractor', 'Internship']

fig, ax = plt.subplots(2,2, sharey=False, figsize=(10,10))

for i, schedule in enumerate(schedules):
    df_schedules = df[df['job_schedule_type'] == schedule]
    df_titles = df_schedules.groupby('job_title_short').size().reset_index(name='count').sort_values(by='count', ascending=False).head(3)

    current_ax = ax[i//2, i%2]
    df_titles.plot(kind='bar', x='job_title_short', y='count', ax=current_ax)
    current_ax.legend().remove()
    current_ax.set_xlabel('')
    current_ax.set_title(schedule)
    current_ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

fig.suptitle('Top 3 jobs per Schedule type')
fig.tight_layout()
plt.show()

# %%
job_roles = ['Senior Data Analyst', 'Senior Data Scientist', 'Senior Data Engineer']

df_exp_skills = df.explode(column='job_skills')
df_exp_skills
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
fig, ax = plt.subplots(3,1, sharex=True)

for i, role in enumerate(job_roles):
    # Get data
    df_role = df_exp_skills[df_exp_skills['job_title_short'] == role]
    df_skills = df_role['job_skills'].value_counts().head(3)
    
    # Plot
    df_skills.plot(kind='barh', x=df_skills.index, y=df_skills.values, ax=ax[i])
    ax[i].set_title(role)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('count')
    ax[i].invert_yaxis()

fig.supylabel('Skills')
fig.suptitle('Top 3 Skills per Role')
fig.tight_layout()
plt.show()
