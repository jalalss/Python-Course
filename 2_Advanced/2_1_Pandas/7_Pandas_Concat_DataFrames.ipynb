# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
data_scientist_df = df[df['job_title_short'] == 'Data Scientist']
data_analyst_df = df[df['job_title_short'] == 'Data Analyst']

combined_df = pd.concat([data_analyst_df, data_scientist_df], ignore_index=True)
combined_df
# Out:
#        job_title_short                                          job_title  \
# 0         Data Analyst                                       Data Analyst
# 1         Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 2         Data Analyst                                       Data Analyst
# 3         Data Analyst                           Stage - Data Analyst F/H
# 4         Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 368356  Data Scientist                           Data Scientist -50065385
# 368357  Data Scientist                    Customer Master Data Specialist
# 368358  Data Scientist               Data Scientist- Hybrid Work Location
# 368359  Data Scientist                      Data Science Python modelling
# 368360  Data Scientist                                 Analytics Engineer
#
#                              job_location                          job_via  \
# ...

# %%
## Create month column
df_copy = df.copy()
df_copy['job_posted_month'] = df_copy['job_posted_date'].dt.strftime('%b')

## Create Q4 data frames
oct_df = df_copy[df_copy['job_posted_month'] == 'Oct']
nov_df = df_copy[df_copy['job_posted_month'] == 'Nov']
dec_df = df_copy[df_copy['job_posted_month'] == 'Dec']

df_q4 = pd.concat([oct_df, nov_df, dec_df], ignore_index=True)
df_q4['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_copy['job_schedule_type'].unique()
# Out:
# array(['Full-time', 'Contractor and Temp work',
#        'Full-time and Internship', 'Temp work', 'Contractor',
#        'Full-time and Part-time', 'Full-time and Temp work',
#        'Full-time and Contractor', 'Part-time', 'Internship', None,
#        'Part-time and Contractor', 'Temp work and Internship',
#        'Full-time, Part-time, and Contractor',
#        'Full-time, Part-time, and Internship',
#        'Full-time, Contractor, and Temp work',
#        'Full-time, Part-time, and Temp work',
#        'Full-time, Temp work, and Internship',
#        'Full-time, Contractor, and Internship',
#        'Part-time and Internship', 'Contractor and Internship',
#        'Part-time and Full-time', 'Part-time and Temp work',
#        'Full-time and Volunteer', 'Contractor, Temp work, and Internship',
#        'Full-time and Per diem', 'Per diem', 'Volunteer',
#        'Part-time, Contractor, and Temp work',
#        'Full-time, Temp work, and Per diem',
# ...

# %%
ft_df = df[df['job_schedule_type'].str.contains('Full-time', na=False)]
pt_df = df[df['job_schedule_type'].str.contains('Part-time', na=False)]
combined_schedules_df = pd.concat([ft_df, pt_df], ignore_index=True).drop_duplicates(subset=['job_title', 'company_name', 'job_posted_date'])
combined_schedules_df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 731506         Data Engineer
# 731507  Senior Data Engineer
# 731509        Data Scientist
# 731511      Business Analyst
# 731513        Data Scientist
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 731506                                     Data Engineer*
# 731507                               Senior Data Engineer
# 731509     Математик, Junior/Middle/Senior Data Scientist
# ...
