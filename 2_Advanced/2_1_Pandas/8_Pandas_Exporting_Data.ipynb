# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.to_csv('data_fame.csv', index=False)
pd.read_csv('data_fame.csv')
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_data_scientist = df[df['job_title_short'] == 'Data Scientist']
df_data_scientist.to_csv('df_data_scientist.csv', index=False)
pd.read_csv('df_data_scientist.csv')
# Out:
#        job_title_short                                          job_title  \
# 0       Data Scientist                                  Data Scientist II
# 1       Data Scientist                             Data Science Team Lead
# 2       Data Scientist                                     Data Scientist
# 3       Data Scientist                                     Data Scientist
# 4       Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 172281  Data Scientist                           Data Scientist -50065385
# 172282  Data Scientist                    Customer Master Data Specialist
# 172283  Data Scientist               Data Scientist- Hybrid Work Location
# 172284  Data Scientist                      Data Science Python modelling
# 172285  Data Scientist                                 Analytics Engineer
#
#                              job_location  \
# ...

# %%
nyc_jobs = df[df['job_location'] == 'New York, NY']
nyc_jobs.to_excel('nyc_jobs.xlsx', index=False)
